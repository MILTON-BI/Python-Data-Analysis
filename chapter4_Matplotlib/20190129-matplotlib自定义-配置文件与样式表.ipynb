# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('classic')
import numpy as np
import pandas as pd

# %% [markdown]
# # 手动配置图形

# %%
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  8.,  23.,  87., 173., 250., 226., 143.,  64.,  23.,   3.]),
#  array([-3.09482864, -2.45597202, -1.81711541, -1.1782588 , -0.53940219,
#          0.09945443,  0.73831104,  1.37716765,  2.01602426,  2.65488088,
#          3.29373749]),
#  <a list of 10 Patch objects>)

# %%
# 用灰色为背景
ax = plt.axes(facecolor='lightgray')
ax.set_axisbelow(True)

# 添加白色网格线
ax.grid(color='w', linestyle='solid')

# 隐藏坐标轴线条
for spine in ax.spines.values():
    spine.set_visible(False)

# 隐藏上边与右边的刻度
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# 弱化刻度与标签
ax.tick_params(color='gray', direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('gray')
for tick in ax.get_yticklabels():
    tick.set_color('gray')

# 设置频次直方图的轮廓颜色和填充颜色
ax.hist(x, bins=12, edgecolor='lightgray', color="gray")


plt.show()

# %% [markdown]
# # 一次性修改默认配置

# %%
# 保存目前的rcParams字典
IPython_default = plt.rcParams.copy()
# print(Ipython_default)

# %%
# 用plt.rc来修改配置参数
from matplotlib import cycler
colors = cycler('color', ['#EE6666', '#3388BB', '#9988DD', '#EECC55', '#88BB44', '#FFBBBB'])

plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
      axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

plt.hist(x)
# Out:
# (array([  8.,  23.,  87., 173., 250., 226., 143.,  64.,  23.,   3.]),
#  array([-3.09482864, -2.45597202, -1.81711541, -1.1782588 , -0.53940219,
#          0.09945443,  0.73831104,  1.37716765,  2.01602426,  2.65488088,
#          3.29373749]),
#  <a list of 10 Patch objects>)

# %%
for i in range(4):
    plt.plot(np.random.randn(10))

# %% [markdown]
# # 样式表

# %%
# 察看前五种风格的样式表
print(plt.style.available[:5])
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight']

# %%
# 创建一个可以画两种基本图形的函数
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')

# %% [markdown]
# ## 默认风格

# %%
# 将rcParams配置还原为默认配置
plt.rcParams.update(IPython_default)
# Out:
# C:\Users\清水木华\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# C:\Users\清水木华\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
hist_and_lines()

# %% [markdown]
# ## FiveThirtyEight风格

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# ## ggplot风格

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# ## bmh风格

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# ## 黑色背景风格

# %%
with plt.style.context('dark_background'):
    hist_and_lines()

# %% [markdown]
# ## 灰度风格

# %%
with plt.style.context('grayscale'):
    hist_and_lines()

# %% [markdown]
# ## seaborn风格

# %%
import seaborn
hist_and_lines()
