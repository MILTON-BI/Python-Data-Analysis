# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(8, 8))
ax = plt.axes()
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-17937cbfe15d> in <module>()
#       2 ax = plt.axes()
#       3 m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
# ----> 4 m.bluemarble(scale=0.5)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in bluemarble(self, ax, scale, **kwargs)
#    3960             return self.warpimage(image='bluemarble',ax=ax,scale=scale,**kwargs)
#    3961         else:
# -> 3962             return self.warpimage(image='bluemarble',scale=scale,**kwargs)
#    3963
#    3964     def shadedrelief(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4166                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4167             # plot warped rgba image.
# -> 4168             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4169             # for hammer projection, use clip path defined by
#    4170             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3317             plt.sci(ret)
#    3318         # set axes limits to fit map region.
# -> 3319         self.set_axes_limits(ax=ax)
#    3320         # clip image to map limbs
#    3321         ret,c = self._cliplimb(ax,ret)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in set_axes_limits(self, ax)
#    3190                     self.projection in _pseudocyl):
#    3191                 # first draw boundary, no fill
# -> 3192                 limb1 = self.drawmapboundary(fill_color='none', ax=ax)
#    3193                 # draw another filled patch, with no boundary.
#    3194                 limb2 = self.drawmapboundary(linewidth=0, ax=ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawmapboundary(self, color, linewidth, fill_color, zorder, ax)
#    1709
#    1710         if limb is not None:
# -> 1711             if limb is not ax.axesPatch:
#    1712                 ax.add_patch(limb)
#    1713             self._mapboundarydrawn = limb
#
# AttributeError: 'AxesSubplot' object has no attribute 'axesPatch'

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None, width=8E6, height=8E6, lat_0=45, lon_0=-100,)
m.etopo(scale=0.5, alpha=0.5)

# 地图上的（经度,纬度）对应图上的（x,y）坐标
x, y = m(-122.3, 47.6)
plt.plot(x, y, 'ok', markersize=8)
plt.text(x, y, 'Seattle', fontsize=12)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(2347268.222744084, 4518079.266407729, 'Seattle')

# %% [markdown]
# # 1.地图投影

# %%
from itertools import chain
def draw_map(m, scale=0.2):
    # 画地貌晕渲图
    m.shadedrelief(scale=scale)
    
    # 用字典形式表示经纬度
    lats = m.drawparallels(np.linspace(-90, 90, 13))
    lons = m.drawmeridians(np.linspace(-180, 180, 13))
    
    # 字典的键是plt2D实例
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # 用循环将所有线设置成需要的样式
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

# %% [markdown]
# ## 1.1 圆柱投影

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution=None, llcrnrlat=-90, urcrnrlat=90, llcrnrlon=-180, urcrnrlon=180,)
draw_map(m)

# %% [markdown]
# ## 1.2 伪圆柱投影

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='moll', resolution=None, lat_0=0, lon_0=0)
draw_map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-71ef2861d9c1> in <module>()
#       1 fig = plt.figure(figsize=(8, 6), edgecolor='w')
#       2 m = Basemap(projection='moll', resolution=None, lat_0=0, lon_0=0)
# ----> 3 draw_map(m)
#
# <ipython-input-8-aee3927a4b82> in draw_map(m, scale)
#       2 def draw_map(m, scale=0.2):
#       3     # 画地貌晕渲图
# ----> 4     m.shadedrelief(scale=scale)
#       5
#       6     # 用字典形式表示经纬度
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3977             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3978         else:
# -> 3979             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3980
#    3981     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4166                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4167             # plot warped rgba image.
# -> 4168             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4169             # for hammer projection, use clip path defined by
#    4170             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3317             plt.sci(ret)
#    3318         # set axes limits to fit map region.
# -> 3319         self.set_axes_limits(ax=ax)
#    3320         # clip image to map limbs
#    3321         ret,c = self._cliplimb(ax,ret)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in set_axes_limits(self, ax)
#    3190                     self.projection in _pseudocyl):
#    3191                 # first draw boundary, no fill
# -> 3192                 limb1 = self.drawmapboundary(fill_color='none', ax=ax)
#    3193                 # draw another filled patch, with no boundary.
#    3194                 limb2 = self.drawmapboundary(linewidth=0, ax=ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawmapboundary(self, color, linewidth, fill_color, zorder, ax)
#    1709
#    1710         if limb is not None:
# -> 1711             if limb is not ax.axesPatch:
#    1712                 ax.add_patch(limb)
#    1713             self._mapboundarydrawn = limb
#
# AttributeError: 'AxesSubplot' object has no attribute 'axesPatch'

# %% [markdown]
# ## 1.3 透视投影

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=0)
draw_map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-11bb51f4489a> in <module>()
#       1 fig = plt.figure(figsize=(8, 8))
#       2 m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=0)
# ----> 3 draw_map(m)
#
# <ipython-input-8-aee3927a4b82> in draw_map(m, scale)
#       2 def draw_map(m, scale=0.2):
#       3     # 画地貌晕渲图
# ----> 4     m.shadedrelief(scale=scale)
#       5
#       6     # 用字典形式表示经纬度
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3977             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3978         else:
# -> 3979             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3980
#    3981     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4166                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4167             # plot warped rgba image.
# -> 4168             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4169             # for hammer projection, use clip path defined by
#    4170             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3317             plt.sci(ret)
#    3318         # set axes limits to fit map region.
# -> 3319         self.set_axes_limits(ax=ax)
#    3320         # clip image to map limbs
#    3321         ret,c = self._cliplimb(ax,ret)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in set_axes_limits(self, ax)
#    3190                     self.projection in _pseudocyl):
#    3191                 # first draw boundary, no fill
# -> 3192                 limb1 = self.drawmapboundary(fill_color='none', ax=ax)
#    3193                 # draw another filled patch, with no boundary.
#    3194                 limb2 = self.drawmapboundary(linewidth=0, ax=ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in drawmapboundary(self, color, linewidth, fill_color, zorder, ax)
#    1709
#    1710         if limb is not None:
# -> 1711             if limb is not ax.axesPatch:
#    1712                 ax.add_patch(limb)
#    1713             self._mapboundarydrawn = limb
#
# AttributeError: 'AxesSubplot' object has no attribute 'axesPatch'

# %% [markdown]
# ## 1.4 圆锥投影

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None, lat_0=50, lon_0=0, lat_1=45, lat_2=55, width=1.6E7, height=1.2E7)
draw_map(m)

# %% [markdown]
# # 2. 绘制地图背景

# %% [markdown]
# ## 2.1 绘制一个海岸线

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))
for i, res in enumerate(['l', 'h']):
    m = Basemap(projection='gnom', lat_0=57.3, lon_0=-6.2, width=90000, height=120000, resolution=res, ax=ax[i])
    m.fillcontinents(color='#FFDDCC', lake_color='#DDEEFF')
    m.drawmapboundary(fill_color='#DDEEFF')
    m.drawcoastlines()
    ax[i].set_title('resolution="{0}"'.format(rees))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e7318ad24a1f> in <module>()
#       1 fig, ax = plt.subplots(1, 2, figsize=(12, 8))
#       2 for i, res in enumerate(['l', 'h']):
# ----> 3     m = Basemap(projection='gnom', lat_0=57.3, lon_0=-6.2, width=90000, height=120000, resolution=res, ax=ax[i])
#       4     m.fillcontinents(color='#FFDDCC', lake_color='#DDEEFF')
#       5     m.drawmapboundary(fill_color='#DDEEFF')
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in __init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#    1110         if self.resolution is not None:
#    1111             self.coastsegs, self.coastpolygontypes =\
# -> 1112             self._readboundarydata('gshhs',as_polygons=True)
#    1113             # reformat for use in matplotlib.patches.Polygon.
#    1114             self.coastpolygons = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _readboundarydata(self, name, as_polygons)
#    1211         read boundary data, clip to map projection region.
#    1212         """
# -> 1213         msg = dedent("""
#    1214         Unable to open boundary dataset file. Only the 'crude' and  'low',
#    1215         resolution datasets are installed by default.
#
# NameError: name 'dedent' is not defined
